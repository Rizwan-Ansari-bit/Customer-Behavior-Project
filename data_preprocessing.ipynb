# %% [markdown]
# **Load Data**

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()

# Adding new column age group

labels=["Young Adult","Adult","Middle-Aged","Senior"]
df["age_group"]=pd.qcut(df["age"],q=4,labels=labels)
df["age_group"]

# Adding new column purchase_frequency_days

frequency_mapping={
    "Fortnightly":14,
    "Weekly":7,
    "Monthly":30,
    "Quarterly":90,
    "Bi-Weekly":14,
    "Every 3 Months":90,
    "Annually":365
}
df["purchase_frequency_days"]=df["frequency_of_purchases"].map(frequency_mapping)
df["purchase_frequency_days"]

# Checking if discount_applied and promo_code_used have same values

(df["discount_applied"]==df["promo_code_used"]).all()

# Both columns have same value so drop promo_code_used columndf.head()

df=df.drop("promo_code_used", axis=1)
df.columns

df.to_csv("cleaned_data.csv")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()

# Adding new column age group

labels=["Young Adult","Adult","Middle-Aged","Senior"]
df["age_group"]=pd.qcut(df["age"],q=4,labels=labels)
df["age_group"]

# Adding new column purchase_frequency_days

frequency_mapping={
    "Fortnightly":14,
    "Weekly":7,
    "Monthly":30,
    "Quarterly":90,
    "Bi-Weekly":14,
    "Every 3 Months":90,
    "Annually":365
}
df["purchase_frequency_days"]=df["frequency_of_purchases"].map(frequency_mapping)
df["purchase_frequency_days"]

# Checking if discount_applied and promo_code_used have same values

(df["discount_applied"]==df["promo_code_used"]).all()

# Both columns have same value so drop promo_code_used column

df=df.drop("promo_code_used", axis=1)
df.columns

df.to_csv("cleaned_data.csv")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()

# Adding new column age group

labels=["Young Adult","Adult","Middle-Aged","Senior"]
df["age_group"]=pd.qcut(df["age"],q=4,labels=labels)
df["age_group"]

# Adding new column purchase_frequency_days

frequency_mapping={
    "Fortnightly":14,
    "Weekly":7,
    "Monthly":30,
    "Quarterly":90,
    "Bi-Weekly":14,
    "Every 3 Months":90,
    "Annually":365
}
df["purchase_frequency_days"]=df["frequency_of_purchases"].map(frequency_mapping)
df["purchase_frequency_days"]

# Checking if discount_applied and promo_code_used have same values

(df["discount_applied"]==df["promo_code_used"]).all()

# Both columns have same value so drop promo_code_used column

df=df.drop("promo_code_used", axis=1)
df.columns

df.to_csv("cleaned_data.csv")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()

# Adding new column age group

labels=["Young Adult","Adult","Middle-Aged","Senior"]
df["age_group"]=pd.qcut(df["age"],q=4,labels=labels)
df["age_group"]

# Adding new column purchase_frequency_days

frequency_mapping={
    "Fortnightly":14,
    "Weekly":7,
    "Monthly":30,
    "Quarterly":90,
    "Bi-Weekly":14,
    "Every 3 Months":90,
    "Annually":365
}
df["purchase_frequency_days"]=df["frequency_of_purchases"].map(frequency_mapping)
df["purchase_frequency_days"]

# Checking if discount_applied and promo_code_used have same values

(df["discount_applied"]==df["promo_code_used"]).all()

# Both columns have same value so drop promo_code_used column

df=df.drop("promo_code_used", axis=1)
df.columns

df.to_csv("cleaned_data.csv")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()

# Adding new column age group

labels=["Young Adult","Adult","Middle-Aged","Senior"]
df["age_group"]=pd.qcut(df["age"],q=4,labels=labels)
df["age_group"]

# Adding new column purchase_frequency_days

frequency_mapping={
    "Fortnightly":14,
    "Weekly":7,
    "Monthly":30,
    "Quarterly":90,
    "Bi-Weekly":14,
    "Every 3 Months":90,
    "Annually":365
}
df["purchase_frequency_days"]=df["frequency_of_purchases"].map(frequency_mapping)
df["purchase_frequency_days"]

# Checking if discount_applied and promo_code_used have same values

(df["discount_applied"]==df["promo_code_used"]).all()

# Both columns have same value so drop promo_code_used column

df=df.drop("promo_code_used", axis=1)
df.columns

df.to_csv("cleaned_data.csv")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()

# Adding new column age group

labels=["Young Adult","Adult","Middle-Aged","Senior"]
df["age_group"]=pd.qcut(df["age"],q=4,labels=labels)
df["age_group"]

# Adding new column purchase_frequency_days

frequency_mapping={
    "Fortnightly":14,
    "Weekly":7,
    "Monthly":30,
    "Quarterly":90,
    "Bi-Weekly":14,
    "Every 3 Months":90,
    "Annually":365
}
df["purchase_frequency_days"]=df["frequency_of_purchases"].map(frequency_mapping)
df["purchase_frequency_days"]

# Checking if discount_applied and promo_code_used have same values

(df["discount_applied"]==df["promo_code_used"]).all()

# Both columns have same value so drop promo_code_used column

df=df.drop("promo_code_used", axis=1)
df.columns

df.to_csv("cleaned_data.csv")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()

# Adding new column age group

labels=["Young Adult","Adult","Middle-Aged","Senior"]
df["age_group"]=pd.qcut(df["age"],q=4,labels=labels)
df["age_group"]

# Adding new column purchase_frequency_days

frequency_mapping={
    "Fortnightly":14,
    "Weekly":7,
    "Monthly":30,
    "Quarterly":90,
    "Bi-Weekly":14,
    "Every 3 Months":90,
    "Annually":365
}
df["purchase_frequency_days"]=df["frequency_of_purchases"].map(frequency_mapping)
df["purchase_frequency_days"]

# Checking if discount_applied and promo_code_used have same values

(df["discount_applied"]==df["promo_code_used"]).all()

# Both columns have same value so drop promo_code_used column

df=df.drop("promo_code_used", axis=1)
df.columns

df.to_csv("cleaned_data.csv")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()

# Adding new column age group

labels=["Young Adult","Adult","Middle-Aged","Senior"]
df["age_group"]=pd.qcut(df["age"],q=4,labels=labels)
df["age_group"]

# Adding new column purchase_frequency_days

frequency_mapping={
    "Fortnightly":14,
    "Weekly":7,
    "Monthly":30,
    "Quarterly":90,
    "Bi-Weekly":14,
    "Every 3 Months":90,
    "Annually":365
}
df["purchase_frequency_days"]=df["frequency_of_purchases"].map(frequency_mapping)
df["purchase_frequency_days"]

# Checking if discount_applied and promo_code_used have same values

(df["discount_applied"]==df["promo_code_used"]).all()

# Both columns have same value so drop promo_code_used column

df=df.drop("promo_code_used", axis=1)
df.columns

df.to_csv("cleaned_data.csv")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()

# Adding new column age group

labels=["Young Adult","Adult","Middle-Aged","Senior"]
df["age_group"]=pd.qcut(df["age"],q=4,labels=labels)
df["age_group"]

# Adding new column purchase_frequency_days

frequency_mapping={
    "Fortnightly":14,
    "Weekly":7,
    "Monthly":30,
    "Quarterly":90,
    "Bi-Weekly":14,
    "Every 3 Months":90,
    "Annually":365
}
df["purchase_frequency_days"]=df["frequency_of_purchases"].map(frequency_mapping)
df["purchase_frequency_days"]

# Checking if discount_applied and promo_code_used have same values

(df["discount_applied"]==df["promo_code_used"]).all()

# Both columns have same value so drop promo_code_used column

df=df.drop("promo_code_used", axis=1)
df.columns

df.to_csv("cleaned_data.csv")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()

# Adding new column age group

labels=["Young Adult","Adult","Middle-Aged","Senior"]
df["age_group"]=pd.qcut(df["age"],q=4,labels=labels)
df["age_group"]

# Adding new column purchase_frequency_days

frequency_mapping={
    "Fortnightly":14,
    "Weekly":7,
    "Monthly":30,
    "Quarterly":90,
    "Bi-Weekly":14,
    "Every 3 Months":90,
    "Annually":365
}
df["purchase_frequency_days"]=df["frequency_of_purchases"].map(frequency_mapping)
df["purchase_frequency_days"]

# Checking if discount_applied and promo_code_used have same values

(df["discount_applied"]==df["promo_code_used"]).all()

# Both columns have same value so drop promo_code_used column

df=df.drop("promo_code_used", axis=1)
df.columns

df.to_csv("cleaned_data.csv")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
import numpy as np
import pandas as pd

df=pd.read_csv("C:/Users/LENOVO/Downloads/HCL/App2/data/customer_shopping_behavior.csv")
df.head(10)

# Altering Column Name

df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns

# Checking Null Values

df.isna().sum()

# Replacing null values in review_rating column by category of reviews median

df["review_rating"]=df.groupby("category")["review_rating"].transform(lambda x: x.fillna(x.median()))
df.isna().sum()

# Adding new column age group

labels=["Young Adult","Adult","Middle-Aged","Senior"]
df["age_group"]=pd.qcut(df["age"],q=4,labels=labels)
df["age_group"]

# Adding new column purchase_frequency_days

frequency_mapping={
    "Fortnightly":14,
    "Weekly":7,
    "Monthly":30,
    "Quarterly":90,
    "Bi-Weekly":14,
    "Every 3 Months":90,
    "Annually":365
}
df["purchase_frequency_days"]=df["frequency_of_purchases"].map(frequency_mapping)
df["purchase_frequency_days"]

# Checking if discount_applied and promo_code_used have same values

(df["discount_applied"]==df["promo_code_used"]).all()

# Both columns have same value so drop promo_code_used column

df=df.drop("promo_code_used", axis=1)
df.columns

df.to_csv("cleaned_data.csv")
